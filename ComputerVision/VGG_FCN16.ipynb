# %%
import cv2, os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.utils import shuffle
import pandas as pd

# %% [markdown]
# **First, download data from:**
#
# https://drive.google.com/file/d/0B0d9ZiqAgFkiOHR1NTJhWVJMNEU/view
#
# and save the downloaded data1 folder in the current directory.

# %%
dir_data = "dataset1/"
dir_seg = dir_data + "/annotations_prepped_train/"
dir_img = dir_data + "/images_prepped_train/"

# %% [markdown]
# **Visualize a single segmentation image**
#
# In this data, there are 12 segmentation classes and the image is from a driving car.

# %%
## seaborn has white grid by default so I will get rid of this.
sns.set_style("whitegrid", {'axes.grid' : False})


ldseg = np.array(os.listdir(dir_seg))
## pick the first image file
fnm = ldseg[0]
print(fnm)

## read in the original image and segmentation labels
seg = cv2.imread(dir_seg + fnm ) # (360, 480, 3)
img_is = cv2.imread(dir_img + fnm )
print("seg.shape={}, img_is.shape={}".format(seg.shape,img_is.shape))

## Check the number of labels
mi, ma = np.min(seg), np.max(seg)
n_classes = ma - mi + 1
print("minimum seg = {}, maximum seg = {}, Total number of segmentation classes = {}".format(mi,ma, n_classes))

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(1,1,1)
ax.imshow(img_is)
ax.set_title("original image")
plt.show()

fig = plt.figure(figsize=(15,10))
for k in range(mi,ma+1):
    ax = fig.add_subplot(3,n_classes/3,k+1)
    ax.imshow((seg == k)*1.0)
    ax.set_title("label = {}".format(k))


plt.show()
# Out:
# 0006R0_f02490.png
# seg.shape=(360, 480, 3), img_is.shape=(360, 480, 3)
# minimum seg = 0, maximum seg = 11, Total number of segmentation classes = 12

# %% [markdown]
# **Data preprocessing: Resize image**
#
# To simplify the problem, I will reshape all the images to the same size: (224,224).
# Why (224,224)?
# This is the iamge shape used in VGG and FCN model in this blog uses a network that takes advantage of VGG structure.
# The FCN model becomes easier to explain when the image shape is (224,224).
# However, FCN does not requires the image shape to be (224,224).
#
# Let's visualize how the resizing make the images look like. The images look fine.

# %%
def give_color_to_seg_img(seg,n_classes):
    '''
    seg : (input_width,input_height,3)
    '''
    
    if len(seg.shape)==3:
        seg = seg[:,:,0]
    seg_img = np.zeros( (seg.shape[0],seg.shape[1],3) ).astype('float')
    colors = sns.color_palette("hls", n_classes)
    
    for c in range(n_classes):
        segc = (seg == c)
        seg_img[:,:,0] += (segc*( colors[c][0] ))
        seg_img[:,:,1] += (segc*( colors[c][1] ))
        seg_img[:,:,2] += (segc*( colors[c][2] ))

    return(seg_img)

# %%
input_height , input_width = 224 , 224
output_height , output_width = 224 , 224


ldseg = np.array(os.listdir(dir_seg))
for fnm in ldseg[np.random.choice(len(ldseg),3,replace=False)]:
    fnm = fnm.split(".")[0]
    seg = cv2.imread(dir_seg + fnm + ".png") # (360, 480, 3)
    img_is = cv2.imread(dir_img + fnm + ".png")
    seg_img = give_color_to_seg_img(seg,n_classes)

    fig = plt.figure(figsize=(20,40))
    ax = fig.add_subplot(1,4,1)
    ax.imshow(seg_img)
    
    ax = fig.add_subplot(1,4,2)
    ax.imshow(img_is/255.0)
    ax.set_title("original image {}".format(img_is.shape[:2]))
    
    ax = fig.add_subplot(1,4,3)
    ax.imshow(cv2.resize(seg_img,(input_height , input_width)))
    
    ax = fig.add_subplot(1,4,4)
    ax.imshow(cv2.resize(img_is,(output_height , output_width))/255.0)
    ax.set_title("resized to {}".format((output_height , output_width)))
    plt.show()

# %%
def getImageArr( path , width , height ):
        img = cv2.imread(path, 1)
        img = np.float32(cv2.resize(img, ( width , height ))) / 127.5 - 1
        return img

def getSegmentationArr( path , nClasses ,  width , height  ):

    seg_labels = np.zeros((  height , width  , nClasses ))
    img = cv2.imread(path, 1)
    img = cv2.resize(img, ( width , height ))
    img = img[:, : , 0]

    for c in range(nClasses):
        seg_labels[: , : , c ] = (img == c ).astype(int)
    ##seg_labels = np.reshape(seg_labels, ( width*height,nClasses  ))
    return seg_labels

# %% [markdown]
# Resize all the images. We have 367 images in this dataset

# %%
images = os.listdir(dir_img)
images.sort()
segmentations  = os.listdir(dir_seg)
segmentations.sort()
    
X = []
Y = []
for im , seg in zip(images,segmentations) :
    X.append( getImageArr(dir_img + im , input_width , input_height )  )
    Y.append( getSegmentationArr( dir_seg + seg , n_classes , output_width , output_height )  )

X, Y = np.array(X) , np.array(Y)
print(X.shape,Y.shape)
# Out:
# (367, 224, 224, 3) (367, 224, 224, 12)

# %% [markdown]
# Import Keras and Tensorflow to develop deep learning FCN models

# %%
## Import usual libraries
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
import keras, sys, time, warnings
from keras.models import *
from keras.layers import *
from keras import optimizers
# Out:
# /home/pirl/anaconda3/envs/edu1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/pirl/anaconda3/envs/edu1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/pirl/anaconda3/envs/edu1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/pirl/anaconda3/envs/edu1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/pirl/anaconda3/envs/edu1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/pirl/anaconda3/envs/edu1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
print("python {}".format(sys.version))
print("keras version {}".format(keras.__version__)); del keras
print("tensorflow version {}".format(tf.__version__))
# Out:
# python 3.6.10 |Anaconda, Inc.| (default, Jan  7 2020, 21:14:29)
# [GCC 7.3.0]
# keras version 2.2.4
# tensorflow version 1.12.0

# %%
## location of VGG weights
VGG_Weights_path = "vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5"

# %% [markdown]
# **Homework** ->
# Make FCN8 based on FCN16

# %%
def FCN16(nClasses ,  input_height=224, input_width=224):
    ## input_height and width must be devisible by 32 because maxpooling with filter size = (2,2) is operated 5 times,
    ## which makes the input_height and width 2^5 = 32 times smaller
    assert input_height%32 == 0
    assert input_width%32 == 0
    IMAGE_ORDERING =  "channels_last" 

    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 224,224,3
    
    ## Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1', data_format=IMAGE_ORDERING )(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool', data_format=IMAGE_ORDERING )(x)
    f1 = x
    
    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool', data_format=IMAGE_ORDERING )(x)
    f2 = x

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool', data_format=IMAGE_ORDERING )(x)
    pool3 = x

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3', data_format=IMAGE_ORDERING )(x)
    pool4 = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool', data_format=IMAGE_ORDERING )(x)## (None, 14, 14, 512) 

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1', data_format=IMAGE_ORDERING )(pool4)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3', data_format=IMAGE_ORDERING )(x)
    pool5 = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool', data_format=IMAGE_ORDERING )(x)## (None, 7, 7, 512)

    #x = Flatten(name='flatten')(x)
    #x = Dense(4096, activation='relu', name='fc1')(x)
    # <--> o = ( Conv2D( 4096 , ( 7 , 7 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)
    # assuming that the input_height = input_width = 224 as in VGG data
    
    #x = Dense(4096, activation='relu', name='fc2')(x)
    # <--> o = ( Conv2D( 4096 , ( 1 , 1 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)   
    # assuming that the input_height = input_width = 224 as in VGG data
    
    #x = Dense(1000 , activation='softmax', name='predictions')(x)
    # <--> o = ( Conv2D( nClasses ,  ( 1 , 1 ) ,kernel_initializer='he_normal' , data_format=IMAGE_ORDERING))(o)
    # assuming that the input_height = input_width = 224 as in VGG data
    
    
    vgg  = Model(  img_input , pool5  )
    vgg.load_weights(VGG_Weights_path) ## loading VGG weights for the encoder parts of FCN8
    
    n = 4096
    o = ( Conv2D( n , ( 7 , 7 ) , activation='relu' , padding='same', name="conv6", data_format=IMAGE_ORDERING))(pool5)
    conv7 = ( Conv2D( n , ( 1 , 1 ) , activation='relu' , padding='same', name="conv7", data_format=IMAGE_ORDERING))(o)
    
    
    ## 4 times upsamping for pool4 layer
    conv7_2 = Conv2DTranspose( nClasses , kernel_size=(2,2) ,  strides=(2,2) , use_bias=False, data_format=IMAGE_ORDERING )(conv7)
    ## (None, 224, 224, 10)
    ## 2 times upsampling for pool411
    pool411 = ( Conv2D( nClasses , ( 1 , 1 ) , activation='relu' , padding='same', name="pool4_11", data_format=IMAGE_ORDERING))(pool4)
      
    o = Add(name="add")([pool411, conv7_2])
    o = Conv2DTranspose( nClasses , kernel_size=(16,16) ,  strides=(16,16) , use_bias=False, data_format=IMAGE_ORDERING )(o)
    o = (Activation('softmax'))(o)
    
    model = Model(img_input, o)

    return model

# %%
model = FCN16(nClasses     = n_classes,  
             input_height = 224, 
             input_width  = 224)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv6 (Conv2D)                  (None, 7, 7, 4096)   102764544   block5_pool[0][0]
# __________________________________________________________________________________________________
# conv7 (Conv2D)                  (None, 7, 7, 4096)   16781312    conv6[0][0]
# __________________________________________________________________________________________________
# pool4_11 (Conv2D)               (None, 14, 14, 12)   6156        block4_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 14, 14, 12)   196608      conv7[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 14, 14, 12)   0           pool4_11[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 224, 224, 12) 36864       add[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 12) 0           conv2d_transpose_2[0][0]
# ==================================================================================================
# Total params: 134,500,172
# Trainable params: 134,500,172
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Split between training and testing data

# %%
train_rate = 0.85
index_train = np.random.choice(X.shape[0],int(X.shape[0]*train_rate),replace=False)
index_test  = list(set(range(X.shape[0])) - set(index_train))
                            
X, Y = shuffle(X,Y)
X_train, y_train = X[index_train],Y[index_train]
X_test, y_test = X[index_test],Y[index_test]
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (311, 224, 224, 3) (311, 224, 224, 12)
# (56, 224, 224, 3) (56, 224, 224, 12)

# %% [markdown]
# **Training starts here**

# %%
sgd = optimizers.SGD(lr=1E-2, decay=5**(-4), momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

hist1 = model.fit(X_train,y_train,
                  validation_data=(X_test,y_test),
                  batch_size=32,epochs=250)
# Out:
# Train on 311 samples, validate on 56 samples
# Epoch 1/250
# 311/311 [==============================] - 25s 82ms/step - loss: 2.4884 - acc: 0.0872 - val_loss: 2.4850 - val_acc: 0.0907
# Epoch 2/250
# 311/311 [==============================] - 8s 25ms/step - loss: 2.4830 - acc: 0.0946 - val_loss: 2.4804 - val_acc: 0.0994
# Epoch 3/250
# 311/311 [==============================] - 8s 25ms/step - loss: 2.4758 - acc: 0.1054 - val_loss: 2.4663 - val_acc: 0.1144
# Epoch 4/250
# 311/311 [==============================] - 8s 25ms/step - loss: 2.4438 - acc: 0.1302 - val_loss: 2.3961 - val_acc: 0.1608
# Epoch 5/250
# 311/311 [==============================] - 8s 25ms/step - loss: 2.2842 - acc: 0.2130 - val_loss: 2.0790 - val_acc: 0.3125
# Epoch 6/250
# 311/311 [==============================] - 8s 25ms/step - loss: 2.0424 - acc: 0.3491 - val_loss: 1.8356 - val_acc: 0.3533
# Epoch 7/250
# 311/311 [==============================] - 8s 25ms/step - loss: 1.7277 - acc: 0.4072 - val_loss: 1.6333 - val_acc: 0.4574
# Epoch 8/250
# 311/311 [==============================] - 8s 25ms/step - loss: 1.4968 - acc: 0.5151 - val_loss: 1.3736 - val_acc: 0.5778
# Epoch 9/250
# 311/311 [==============================] - 8s 25ms/step - loss: 1.3114 - acc: 0.6135 - val_loss: 1.5929 - val_acc: 0.6128
# Epoch 10/250
# 311/311 [==============================] - 8s 25ms/step - loss: 1.2040 - acc: 0.6595 - val_loss: 1.1506 - val_acc: 0.6648
# Epoch 11/250
# 311/311 [==============================] - 8s 25ms/step - loss: 1.0741 - acc: 0.6804 - val_loss: 1.0762 - val_acc: 0.6705
# Epoch 12/250
# 311/311 [==============================] - 8s 25ms/step - loss: 1.0188 - acc: 0.6867 - val_loss: 1.0347 - val_acc: 0.6792
# Epoch 13/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.9836 - acc: 0.6942 - val_loss: 1.0344 - val_acc: 0.6806
# Epoch 14/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.9681 - acc: 0.7004 - val_loss: 0.9930 - val_acc: 0.6926
# Epoch 15/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.9238 - acc: 0.7151 - val_loss: 0.9347 - val_acc: 0.7185
# Epoch 16/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.9203 - acc: 0.7287 - val_loss: 0.9316 - val_acc: 0.7249
# Epoch 17/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.8647 - acc: 0.7442 - val_loss: 0.8819 - val_acc: 0.7375
# Epoch 18/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.8347 - acc: 0.7514 - val_loss: 0.8552 - val_acc: 0.7441
# Epoch 19/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.8105 - acc: 0.7562 - val_loss: 0.8375 - val_acc: 0.7482
# Epoch 20/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.7997 - acc: 0.7586 - val_loss: 0.8175 - val_acc: 0.7524
# Epoch 21/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.7748 - acc: 0.7649 - val_loss: 0.8051 - val_acc: 0.7561
# Epoch 22/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.7859 - acc: 0.7631 - val_loss: 0.8074 - val_acc: 0.7531
# Epoch 23/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.7460 - acc: 0.7733 - val_loss: 0.7766 - val_acc: 0.7651
# Epoch 24/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.7356 - acc: 0.7777 - val_loss: 0.7659 - val_acc: 0.7699
# Epoch 25/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.7169 - acc: 0.7843 - val_loss: 0.7501 - val_acc: 0.7749
# Epoch 26/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.7015 - acc: 0.7909 - val_loss: 0.7559 - val_acc: 0.7761
# Epoch 27/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6964 - acc: 0.7937 - val_loss: 0.7280 - val_acc: 0.7844
# Epoch 28/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6794 - acc: 0.8002 - val_loss: 0.7273 - val_acc: 0.7856
# Epoch 29/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6690 - acc: 0.8042 - val_loss: 0.7159 - val_acc: 0.7881
# Epoch 30/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.7142 - acc: 0.7935 - val_loss: 0.7256 - val_acc: 0.7880
# Epoch 31/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6600 - acc: 0.8083 - val_loss: 0.7003 - val_acc: 0.7941
# Epoch 32/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6477 - acc: 0.8119 - val_loss: 0.6922 - val_acc: 0.7970
# Epoch 33/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6342 - acc: 0.8170 - val_loss: 0.6797 - val_acc: 0.8012
# Epoch 34/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6264 - acc: 0.8194 - val_loss: 0.6829 - val_acc: 0.7997
# Epoch 35/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6212 - acc: 0.8210 - val_loss: 0.6752 - val_acc: 0.8027
# Epoch 36/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6181 - acc: 0.8217 - val_loss: 0.6593 - val_acc: 0.8082
# Epoch 37/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6046 - acc: 0.8262 - val_loss: 0.6543 - val_acc: 0.8095
# Epoch 38/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.6005 - acc: 0.8270 - val_loss: 0.6668 - val_acc: 0.8059
# Epoch 39/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5985 - acc: 0.8277 - val_loss: 0.6428 - val_acc: 0.8138
# Epoch 40/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5899 - acc: 0.8308 - val_loss: 0.6592 - val_acc: 0.8085
# Epoch 41/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5861 - acc: 0.8311 - val_loss: 0.6444 - val_acc: 0.8128
# Epoch 42/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5799 - acc: 0.8331 - val_loss: 0.6321 - val_acc: 0.8164
# Epoch 43/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5748 - acc: 0.8345 - val_loss: 0.6402 - val_acc: 0.8150
# Epoch 44/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5704 - acc: 0.8356 - val_loss: 0.6201 - val_acc: 0.8204
# Epoch 45/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5742 - acc: 0.8341 - val_loss: 0.6162 - val_acc: 0.8208
# Epoch 46/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5590 - acc: 0.8392 - val_loss: 0.6158 - val_acc: 0.8215
# Epoch 47/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5544 - acc: 0.8406 - val_loss: 0.6104 - val_acc: 0.8232
# Epoch 48/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5494 - acc: 0.8419 - val_loss: 0.6066 - val_acc: 0.8239
# Epoch 49/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5464 - acc: 0.8426 - val_loss: 0.6070 - val_acc: 0.8246
# Epoch 50/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5558 - acc: 0.8403 - val_loss: 0.6010 - val_acc: 0.8261
# Epoch 51/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5384 - acc: 0.8452 - val_loss: 0.5957 - val_acc: 0.8277
# Epoch 52/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5343 - acc: 0.8466 - val_loss: 0.5917 - val_acc: 0.8287
# Epoch 53/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5310 - acc: 0.8474 - val_loss: 0.5998 - val_acc: 0.8266
# Epoch 54/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5297 - acc: 0.8480 - val_loss: 0.5878 - val_acc: 0.8294
# Epoch 55/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5760 - acc: 0.8329 - val_loss: 0.6048 - val_acc: 0.8247
# Epoch 56/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5330 - acc: 0.8471 - val_loss: 0.5915 - val_acc: 0.8283
# Epoch 57/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5250 - acc: 0.8494 - val_loss: 0.5835 - val_acc: 0.8302
# Epoch 58/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5194 - acc: 0.8510 - val_loss: 0.5812 - val_acc: 0.8314
# Epoch 59/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5179 - acc: 0.8515 - val_loss: 0.5902 - val_acc: 0.8291
# Epoch 60/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5161 - acc: 0.8520 - val_loss: 0.5819 - val_acc: 0.8317
# Epoch 61/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5203 - acc: 0.8511 - val_loss: 0.5856 - val_acc: 0.8306
# Epoch 62/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5108 - acc: 0.8533 - val_loss: 0.5706 - val_acc: 0.8350
# Epoch 63/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5069 - acc: 0.8550 - val_loss: 0.5681 - val_acc: 0.8358
# Epoch 64/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5050 - acc: 0.8555 - val_loss: 0.5673 - val_acc: 0.8363
# Epoch 65/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5007 - acc: 0.8569 - val_loss: 0.5702 - val_acc: 0.8351
# Epoch 66/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5040 - acc: 0.8555 - val_loss: 0.5708 - val_acc: 0.8350
# Epoch 67/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5015 - acc: 0.8566 - val_loss: 0.5607 - val_acc: 0.8382
# Epoch 68/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4954 - acc: 0.8584 - val_loss: 0.5637 - val_acc: 0.8375
# Epoch 69/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.5020 - acc: 0.8565 - val_loss: 0.5581 - val_acc: 0.8387
# Epoch 70/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4913 - acc: 0.8599 - val_loss: 0.5646 - val_acc: 0.8367
# Epoch 71/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4930 - acc: 0.8593 - val_loss: 0.5639 - val_acc: 0.8381
# Epoch 72/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4904 - acc: 0.8603 - val_loss: 0.5624 - val_acc: 0.8384
# Epoch 73/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4872 - acc: 0.8611 - val_loss: 0.5611 - val_acc: 0.8383
# Epoch 74/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4880 - acc: 0.8609 - val_loss: 0.5682 - val_acc: 0.8365
# Epoch 75/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4828 - acc: 0.8625 - val_loss: 0.5522 - val_acc: 0.8408
# Epoch 76/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4805 - acc: 0.8634 - val_loss: 0.5506 - val_acc: 0.8412
# Epoch 77/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4862 - acc: 0.8612 - val_loss: 0.5543 - val_acc: 0.8390
# Epoch 78/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4797 - acc: 0.8635 - val_loss: 0.5492 - val_acc: 0.8421
# Epoch 79/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4761 - acc: 0.8645 - val_loss: 0.5491 - val_acc: 0.8419
# Epoch 80/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4758 - acc: 0.8647 - val_loss: 0.5473 - val_acc: 0.8429
# Epoch 81/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4751 - acc: 0.8650 - val_loss: 0.5494 - val_acc: 0.8424
# Epoch 82/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4700 - acc: 0.8668 - val_loss: 0.5452 - val_acc: 0.8435
# Epoch 83/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4696 - acc: 0.8667 - val_loss: 0.5478 - val_acc: 0.8429
# Epoch 84/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4747 - acc: 0.8649 - val_loss: 0.5707 - val_acc: 0.8358
# Epoch 85/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4869 - acc: 0.8616 - val_loss: 0.5461 - val_acc: 0.8429
# Epoch 86/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4661 - acc: 0.8678 - val_loss: 0.5408 - val_acc: 0.8447
# Epoch 87/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4644 - acc: 0.8684 - val_loss: 0.5401 - val_acc: 0.8452
# Epoch 88/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4620 - acc: 0.8694 - val_loss: 0.5570 - val_acc: 0.8414
# Epoch 89/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4784 - acc: 0.8636 - val_loss: 0.5389 - val_acc: 0.8456
# Epoch 90/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4604 - acc: 0.8697 - val_loss: 0.5368 - val_acc: 0.8460
# Epoch 91/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4605 - acc: 0.8698 - val_loss: 0.5383 - val_acc: 0.8458
# Epoch 92/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4576 - acc: 0.8707 - val_loss: 0.5381 - val_acc: 0.8455
# Epoch 93/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4564 - acc: 0.8711 - val_loss: 0.5349 - val_acc: 0.8470
# Epoch 94/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4553 - acc: 0.8716 - val_loss: 0.5419 - val_acc: 0.8451
# Epoch 95/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4533 - acc: 0.8720 - val_loss: 0.5359 - val_acc: 0.8465
# Epoch 96/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4541 - acc: 0.8720 - val_loss: 0.5365 - val_acc: 0.8467
# Epoch 97/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4524 - acc: 0.8724 - val_loss: 0.5328 - val_acc: 0.8482
# Epoch 98/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4521 - acc: 0.8723 - val_loss: 0.5382 - val_acc: 0.8455
# Epoch 99/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4561 - acc: 0.8714 - val_loss: 0.5306 - val_acc: 0.8484
# Epoch 100/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4472 - acc: 0.8741 - val_loss: 0.5305 - val_acc: 0.8482
# Epoch 101/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4487 - acc: 0.8735 - val_loss: 0.5310 - val_acc: 0.8485
# Epoch 102/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4468 - acc: 0.8744 - val_loss: 0.5302 - val_acc: 0.8486
# Epoch 103/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4442 - acc: 0.8752 - val_loss: 0.5267 - val_acc: 0.8498
# Epoch 104/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4428 - acc: 0.8756 - val_loss: 0.5299 - val_acc: 0.8492
# Epoch 105/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4455 - acc: 0.8749 - val_loss: 0.5272 - val_acc: 0.8496
# Epoch 106/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4407 - acc: 0.8763 - val_loss: 0.5269 - val_acc: 0.8498
# Epoch 107/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4409 - acc: 0.8761 - val_loss: 0.5243 - val_acc: 0.8507
# Epoch 108/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4422 - acc: 0.8757 - val_loss: 0.5350 - val_acc: 0.8473
# Epoch 109/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4462 - acc: 0.8740 - val_loss: 0.5211 - val_acc: 0.8507
# Epoch 110/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4378 - acc: 0.8771 - val_loss: 0.5221 - val_acc: 0.8515
# Epoch 111/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4393 - acc: 0.8766 - val_loss: 0.5274 - val_acc: 0.8496
# Epoch 112/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4382 - acc: 0.8771 - val_loss: 0.5213 - val_acc: 0.8515
# Epoch 113/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4360 - acc: 0.8779 - val_loss: 0.5201 - val_acc: 0.8515
# Epoch 114/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4357 - acc: 0.8781 - val_loss: 0.5274 - val_acc: 0.8498
# Epoch 115/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4387 - acc: 0.8768 - val_loss: 0.5187 - val_acc: 0.8522
# Epoch 116/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4324 - acc: 0.8789 - val_loss: 0.5207 - val_acc: 0.8515
# Epoch 117/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4326 - acc: 0.8789 - val_loss: 0.5183 - val_acc: 0.8525
# Epoch 118/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4318 - acc: 0.8791 - val_loss: 0.5222 - val_acc: 0.8512
# Epoch 119/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4335 - acc: 0.8787 - val_loss: 0.5204 - val_acc: 0.8519
# Epoch 120/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4293 - acc: 0.8800 - val_loss: 0.5248 - val_acc: 0.8512
# Epoch 121/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4333 - acc: 0.8785 - val_loss: 0.5310 - val_acc: 0.8493
# Epoch 122/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4293 - acc: 0.8798 - val_loss: 0.5157 - val_acc: 0.8534
# Epoch 123/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4261 - acc: 0.8809 - val_loss: 0.5172 - val_acc: 0.8529
# Epoch 124/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4280 - acc: 0.8802 - val_loss: 0.5232 - val_acc: 0.8509
# Epoch 125/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4279 - acc: 0.8802 - val_loss: 0.5148 - val_acc: 0.8528
# Epoch 126/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4240 - acc: 0.8815 - val_loss: 0.5198 - val_acc: 0.8524
# Epoch 127/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4257 - acc: 0.8810 - val_loss: 0.5235 - val_acc: 0.8517
# Epoch 128/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4291 - acc: 0.8797 - val_loss: 0.5146 - val_acc: 0.8535
# Epoch 129/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4235 - acc: 0.8815 - val_loss: 0.5164 - val_acc: 0.8527
# Epoch 130/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4221 - acc: 0.8820 - val_loss: 0.5184 - val_acc: 0.8525
# Epoch 131/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4204 - acc: 0.8827 - val_loss: 0.5151 - val_acc: 0.8533
# Epoch 132/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4197 - acc: 0.8829 - val_loss: 0.5146 - val_acc: 0.8538
# Epoch 133/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4320 - acc: 0.8789 - val_loss: 0.5136 - val_acc: 0.8537
# Epoch 134/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4192 - acc: 0.8831 - val_loss: 0.5125 - val_acc: 0.8542
# Epoch 135/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4174 - acc: 0.8835 - val_loss: 0.5126 - val_acc: 0.8543
# Epoch 136/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4203 - acc: 0.8824 - val_loss: 0.5226 - val_acc: 0.8522
# Epoch 137/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4200 - acc: 0.8825 - val_loss: 0.5117 - val_acc: 0.8546
# Epoch 138/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4168 - acc: 0.8838 - val_loss: 0.5092 - val_acc: 0.8556
# Epoch 139/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4145 - acc: 0.8845 - val_loss: 0.5092 - val_acc: 0.8552
# Epoch 140/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4149 - acc: 0.8842 - val_loss: 0.5083 - val_acc: 0.8552
# Epoch 141/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4134 - acc: 0.8848 - val_loss: 0.5085 - val_acc: 0.8555
# Epoch 142/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4130 - acc: 0.8850 - val_loss: 0.5123 - val_acc: 0.8548
# Epoch 143/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4141 - acc: 0.8845 - val_loss: 0.5091 - val_acc: 0.8549
# Epoch 144/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4118 - acc: 0.8852 - val_loss: 0.5152 - val_acc: 0.8545
# Epoch 145/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4145 - acc: 0.8843 - val_loss: 0.5159 - val_acc: 0.8531
# Epoch 146/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4115 - acc: 0.8853 - val_loss: 0.5088 - val_acc: 0.8547
# Epoch 147/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4134 - acc: 0.8847 - val_loss: 0.5246 - val_acc: 0.8505
# Epoch 148/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4173 - acc: 0.8834 - val_loss: 0.5072 - val_acc: 0.8561
# Epoch 149/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4109 - acc: 0.8857 - val_loss: 0.5066 - val_acc: 0.8559
# Epoch 150/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4085 - acc: 0.8863 - val_loss: 0.5102 - val_acc: 0.8558
# Epoch 151/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4076 - acc: 0.8866 - val_loss: 0.5049 - val_acc: 0.8564
# Epoch 152/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4085 - acc: 0.8862 - val_loss: 0.5143 - val_acc: 0.8544
# Epoch 153/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4079 - acc: 0.8864 - val_loss: 0.5065 - val_acc: 0.8565
# Epoch 154/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4065 - acc: 0.8867 - val_loss: 0.5097 - val_acc: 0.8556
# Epoch 155/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4087 - acc: 0.8859 - val_loss: 0.5129 - val_acc: 0.8552
# Epoch 156/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4128 - acc: 0.8848 - val_loss: 0.5048 - val_acc: 0.8564
# Epoch 157/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4044 - acc: 0.8875 - val_loss: 0.5046 - val_acc: 0.8568
# Epoch 158/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4042 - acc: 0.8875 - val_loss: 0.5064 - val_acc: 0.8567
# Epoch 159/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4064 - acc: 0.8867 - val_loss: 0.5130 - val_acc: 0.8549
# Epoch 160/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4051 - acc: 0.8871 - val_loss: 0.5022 - val_acc: 0.8570
# Epoch 161/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4065 - acc: 0.8867 - val_loss: 0.5028 - val_acc: 0.8570
# Epoch 162/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4023 - acc: 0.8881 - val_loss: 0.5034 - val_acc: 0.8572
# Epoch 163/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4019 - acc: 0.8882 - val_loss: 0.5038 - val_acc: 0.8570
# Epoch 164/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4029 - acc: 0.8879 - val_loss: 0.5053 - val_acc: 0.8569
# Epoch 165/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4012 - acc: 0.8884 - val_loss: 0.5029 - val_acc: 0.8569
# Epoch 166/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4006 - acc: 0.8885 - val_loss: 0.5037 - val_acc: 0.8567
# Epoch 167/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4003 - acc: 0.8887 - val_loss: 0.5116 - val_acc: 0.8553
# Epoch 168/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4005 - acc: 0.8884 - val_loss: 0.5017 - val_acc: 0.8577
# Epoch 169/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3987 - acc: 0.8893 - val_loss: 0.5028 - val_acc: 0.8576
# Epoch 170/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3981 - acc: 0.8895 - val_loss: 0.5031 - val_acc: 0.8573
# Epoch 171/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3974 - acc: 0.8896 - val_loss: 0.5040 - val_acc: 0.8572
# Epoch 172/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3970 - acc: 0.8897 - val_loss: 0.5038 - val_acc: 0.8574
# Epoch 173/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3978 - acc: 0.8893 - val_loss: 0.5082 - val_acc: 0.8566
# Epoch 174/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4015 - acc: 0.8884 - val_loss: 0.5016 - val_acc: 0.8576
# Epoch 175/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3960 - acc: 0.8900 - val_loss: 0.5013 - val_acc: 0.8578
# Epoch 176/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3974 - acc: 0.8895 - val_loss: 0.5020 - val_acc: 0.8578
# Epoch 177/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3954 - acc: 0.8901 - val_loss: 0.5043 - val_acc: 0.8574
# Epoch 178/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3969 - acc: 0.8896 - val_loss: 0.5006 - val_acc: 0.8581
# Epoch 179/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3946 - acc: 0.8904 - val_loss: 0.5062 - val_acc: 0.8570
# Epoch 180/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3949 - acc: 0.8903 - val_loss: 0.5015 - val_acc: 0.8573
# Epoch 181/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3975 - acc: 0.8894 - val_loss: 0.4985 - val_acc: 0.8585
# Epoch 182/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3947 - acc: 0.8903 - val_loss: 0.4996 - val_acc: 0.8582
# Epoch 183/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3951 - acc: 0.8901 - val_loss: 0.5093 - val_acc: 0.8563
# Epoch 184/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3957 - acc: 0.8899 - val_loss: 0.5003 - val_acc: 0.8583
# Epoch 185/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3927 - acc: 0.8910 - val_loss: 0.4991 - val_acc: 0.8583
# Epoch 186/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3912 - acc: 0.8915 - val_loss: 0.5002 - val_acc: 0.8581
# Epoch 187/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3913 - acc: 0.8913 - val_loss: 0.4974 - val_acc: 0.8587
# Epoch 188/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3931 - acc: 0.8907 - val_loss: 0.5010 - val_acc: 0.8579
# Epoch 189/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3912 - acc: 0.8914 - val_loss: 0.4981 - val_acc: 0.8588
# Epoch 190/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3900 - acc: 0.8917 - val_loss: 0.4992 - val_acc: 0.8587
# Epoch 191/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3911 - acc: 0.8914 - val_loss: 0.4980 - val_acc: 0.8588
# Epoch 192/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3887 - acc: 0.8922 - val_loss: 0.4990 - val_acc: 0.8589
# Epoch 193/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3894 - acc: 0.8919 - val_loss: 0.5022 - val_acc: 0.8578
# Epoch 194/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3903 - acc: 0.8916 - val_loss: 0.4999 - val_acc: 0.8586
# Epoch 195/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3880 - acc: 0.8923 - val_loss: 0.5036 - val_acc: 0.8580
# Epoch 196/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3933 - acc: 0.8906 - val_loss: 0.5046 - val_acc: 0.8578
# Epoch 197/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3881 - acc: 0.8921 - val_loss: 0.4981 - val_acc: 0.8589
# Epoch 198/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3866 - acc: 0.8928 - val_loss: 0.4965 - val_acc: 0.8592
# Epoch 199/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3884 - acc: 0.8921 - val_loss: 0.4963 - val_acc: 0.8593
# Epoch 200/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3862 - acc: 0.8929 - val_loss: 0.4984 - val_acc: 0.8587
# Epoch 201/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3859 - acc: 0.8930 - val_loss: 0.4980 - val_acc: 0.8590
# Epoch 202/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3861 - acc: 0.8928 - val_loss: 0.4967 - val_acc: 0.8594
# Epoch 203/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3858 - acc: 0.8929 - val_loss: 0.4946 - val_acc: 0.8597
# Epoch 204/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3874 - acc: 0.8924 - val_loss: 0.4958 - val_acc: 0.8592
# Epoch 205/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3857 - acc: 0.8929 - val_loss: 0.4951 - val_acc: 0.8595
# Epoch 206/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3854 - acc: 0.8932 - val_loss: 0.4937 - val_acc: 0.8598
# Epoch 207/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3841 - acc: 0.8935 - val_loss: 0.4955 - val_acc: 0.8597
# Epoch 208/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3850 - acc: 0.8932 - val_loss: 0.4952 - val_acc: 0.8594
# Epoch 209/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3840 - acc: 0.8934 - val_loss: 0.4943 - val_acc: 0.8602
# Epoch 210/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3822 - acc: 0.8941 - val_loss: 0.4954 - val_acc: 0.8596
# Epoch 211/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3832 - acc: 0.8938 - val_loss: 0.4948 - val_acc: 0.8599
# Epoch 212/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3830 - acc: 0.8937 - val_loss: 0.4947 - val_acc: 0.8599
# Epoch 213/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3818 - acc: 0.8942 - val_loss: 0.4954 - val_acc: 0.8600
# Epoch 214/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3822 - acc: 0.8940 - val_loss: 0.4943 - val_acc: 0.8601
# Epoch 215/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3831 - acc: 0.8936 - val_loss: 0.4957 - val_acc: 0.8600
# Epoch 216/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3811 - acc: 0.8944 - val_loss: 0.4977 - val_acc: 0.8595
# Epoch 217/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3832 - acc: 0.8936 - val_loss: 0.5188 - val_acc: 0.8551
# Epoch 218/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.4105 - acc: 0.8845 - val_loss: 0.4908 - val_acc: 0.8598
# Epoch 219/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3828 - acc: 0.8936 - val_loss: 0.4939 - val_acc: 0.8598
# Epoch 220/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3805 - acc: 0.8944 - val_loss: 0.4934 - val_acc: 0.8601
# Epoch 221/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3797 - acc: 0.8947 - val_loss: 0.4942 - val_acc: 0.8601
# Epoch 222/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3792 - acc: 0.8949 - val_loss: 0.4941 - val_acc: 0.8602
# Epoch 223/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3792 - acc: 0.8948 - val_loss: 0.4935 - val_acc: 0.8603
# Epoch 224/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3789 - acc: 0.8950 - val_loss: 0.4944 - val_acc: 0.8603
# Epoch 225/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3780 - acc: 0.8952 - val_loss: 0.4952 - val_acc: 0.8604
# Epoch 226/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3783 - acc: 0.8951 - val_loss: 0.4948 - val_acc: 0.8603
# Epoch 227/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3775 - acc: 0.8954 - val_loss: 0.4943 - val_acc: 0.8599
# Epoch 228/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3808 - acc: 0.8943 - val_loss: 0.4935 - val_acc: 0.8603
# Epoch 229/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3769 - acc: 0.8955 - val_loss: 0.4928 - val_acc: 0.8605
# Epoch 230/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3790 - acc: 0.8949 - val_loss: 0.5011 - val_acc: 0.8586
# Epoch 231/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3779 - acc: 0.8951 - val_loss: 0.4928 - val_acc: 0.8606
# Epoch 232/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3764 - acc: 0.8957 - val_loss: 0.4925 - val_acc: 0.8607
# Epoch 233/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3763 - acc: 0.8958 - val_loss: 0.4921 - val_acc: 0.8607
# Epoch 234/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3765 - acc: 0.8956 - val_loss: 0.4917 - val_acc: 0.8609
# Epoch 235/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3752 - acc: 0.8960 - val_loss: 0.4949 - val_acc: 0.8606
# Epoch 236/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3759 - acc: 0.8958 - val_loss: 0.4933 - val_acc: 0.8607
# Epoch 237/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3751 - acc: 0.8960 - val_loss: 0.4968 - val_acc: 0.8600
# Epoch 238/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3758 - acc: 0.8958 - val_loss: 0.4950 - val_acc: 0.8603
# Epoch 239/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3743 - acc: 0.8963 - val_loss: 0.4916 - val_acc: 0.8611
# Epoch 240/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3747 - acc: 0.8961 - val_loss: 0.4976 - val_acc: 0.8601
# Epoch 241/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3795 - acc: 0.8944 - val_loss: 0.4980 - val_acc: 0.8597
# Epoch 242/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3749 - acc: 0.8959 - val_loss: 0.4945 - val_acc: 0.8604
# Epoch 243/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3733 - acc: 0.8966 - val_loss: 0.4929 - val_acc: 0.8611
# Epoch 244/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3735 - acc: 0.8965 - val_loss: 0.4921 - val_acc: 0.8611
# Epoch 245/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3726 - acc: 0.8967 - val_loss: 0.4926 - val_acc: 0.8612
# Epoch 246/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3724 - acc: 0.8968 - val_loss: 0.4935 - val_acc: 0.8609
# Epoch 247/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3722 - acc: 0.8969 - val_loss: 0.4933 - val_acc: 0.8611
# Epoch 248/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3732 - acc: 0.8965 - val_loss: 0.4937 - val_acc: 0.8609
# Epoch 249/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3724 - acc: 0.8969 - val_loss: 0.4931 - val_acc: 0.8609
# Epoch 250/250
# 311/311 [==============================] - 8s 25ms/step - loss: 0.3724 - acc: 0.8968 - val_loss: 0.4932 - val_acc: 0.8607

# %% [markdown]
# Plot the change in loss over epochs

# %%
for key in ['loss', 'val_loss']:
    plt.plot(hist1.history[key],label=key)
plt.legend()
plt.show()

# %% [markdown]
# Calculate intersection over union for each segmentation class

# %%
y_pred = model.predict(X_test)
y_predi = np.argmax(y_pred, axis=3)
y_testi = np.argmax(y_test, axis=3)
print(y_testi.shape,y_predi.shape)
# Out:
# (56, 224, 224) (56, 224, 224)

# %%
def IoU(Yi,y_predi):
    ## mean Intersection over Union
    ## Mean IoU = TP/(FN + TP + FP)

    IoUs = []
    Nclass = int(np.max(Yi)) + 1
    for c in range(Nclass):
        TP = np.sum( (Yi == c)&(y_predi==c) )
        FP = np.sum( (Yi != c)&(y_predi==c) )
        FN = np.sum( (Yi == c)&(y_predi != c)) 
        IoU = TP/float(TP + FP + FN)
        print("class {:02.0f}: #TP={:6.0f}, #FP={:6.0f}, #FN={:5.0f}, IoU={:4.3f}".format(c,TP,FP,FN,IoU))
        IoUs.append(IoU)
    mIoU = np.mean(IoUs)
    print("_________________")
    print("Mean IoU: {:4.3f}".format(mIoU))

# %%
IoU(y_testi,y_predi)
# Out:
# class 00: #TP=417764, #FP= 41991, #FN=27047, IoU=0.858
# class 01: #TP=601186, #FP=128690, #FN=42309, IoU=0.779
# class 02: #TP=     5, #FP=    54, #FN=36681, IoU=0.000
# class 03: #TP=854495, #FP= 31829, #FN=37154, IoU=0.925
# class 04: #TP=110515, #FP= 34548, #FN=42766, IoU=0.588
# class 05: #TP=224489, #FP= 72349, #FN=49718, IoU=0.648
# class 06: #TP=  4953, #FP=  4311, #FN=33806, IoU=0.115
# class 07: #TP= 25324, #FP= 14611, #FN=23785, IoU=0.397
# class 08: #TP=126821, #FP= 29766, #FN=28597, IoU=0.685
# class 09: #TP=  1521, #FP=  2923, #FN=18601, IoU=0.066
# class 10: #TP=   330, #FP=   508, #FN= 8910, IoU=0.034
# class 11: #TP= 51007, #FP= 29866, #FN=42072, IoU=0.415
# _________________
# Mean IoU: 0.459

# %% [markdown]
# **Visualize the model performance**
#
#
# Looks reasonable!

# %%
shape = (224,224)
n_classes= 10

for i in range(10):
    img_is  = (X_test[i] + 1)*(255.0/2)
    seg = y_predi[i]
    segtest = y_testi[i]

    fig = plt.figure(figsize=(10,30))    
    ax = fig.add_subplot(1,3,1)
    ax.imshow(img_is/255.0)
    ax.set_title("original")
    
    ax = fig.add_subplot(1,3,2)
    ax.imshow(give_color_to_seg_img(seg,n_classes))
    ax.set_title("predicted class")
    
    ax = fig.add_subplot(1,3,3)
    ax.imshow(give_color_to_seg_img(segtest,n_classes))
    ax.set_title("true class")
    plt.show()
