# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#환경-설치" data-toc-modified-id="환경-설치-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>환경 설치</a></span><ul class="toc-item"><li><span><a href="#설치-확인" data-toc-modified-id="설치-확인-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>설치 확인</a></span></li></ul></li><li><span><a href="#이미지-다루기" data-toc-modified-id="이미지-다루기-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>이미지 다루기</a></span><ul class="toc-item"><li><span><a href="#이미지-읽기" data-toc-modified-id="이미지-읽기-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>이미지 읽기</a></span></li><li><span><a href="#이미지-보기" data-toc-modified-id="이미지-보기-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>이미지 보기</a></span></li><li><span><a href="#이미지-저장하기" data-toc-modified-id="이미지-저장하기-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>이미지 저장하기</a></span></li><li><span><a href="#Matplotlib-사용하기" data-toc-modified-id="Matplotlib-사용하기-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Matplotlib 사용하기</a></span></li></ul></li><li><span><a href="#도형-그리기" data-toc-modified-id="도형-그리기-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>도형 그리기</a></span><ul class="toc-item"><li><span><a href="#Digital-Image" data-toc-modified-id="Digital-Image-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Digital Image</a></span></li><li><span><a href="#Line-그리기" data-toc-modified-id="Line-그리기-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Line 그리기</a></span></li><li><span><a href="#사각형-그리기" data-toc-modified-id="사각형-그리기-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>사각형 그리기</a></span></li><li><span><a href="#원-그리기" data-toc-modified-id="원-그리기-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>원 그리기</a></span></li><li><span><a href="#이미지에-Text-추가" data-toc-modified-id="이미지에-Text-추가-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>이미지에 Text 추가</a></span></li><li><span><a href="#그-외의-도형" data-toc-modified-id="그-외의-도형-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>그 외의 도형</a></span></li></ul></li><li><span><a href="#Basic-Operation" data-toc-modified-id="Basic-Operation-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Basic Operation</a></span><ul class="toc-item"><li><span><a href="#Pixel-Value" data-toc-modified-id="Pixel-Value-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Pixel Value</a></span></li><li><span><a href="#이미지-ROI" data-toc-modified-id="이미지-ROI-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>이미지 ROI</a></span></li></ul></li><li><span><a href="#이미지-연산" data-toc-modified-id="이미지-연산-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>이미지 연산</a></span><ul class="toc-item"><li><span><a href="#이미지-더하기" data-toc-modified-id="이미지-더하기-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>이미지 더하기</a></span></li><li><span><a href="#이미지-Blending" data-toc-modified-id="이미지-Blending-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>이미지 Blending</a></span></li></ul></li></ul></div>

# %% [markdown]
# OpenCV tutorial
# 출처 : https://opencv-python.readthedocs.io/

# %% [markdown]
# # 환경 설치
# conda create -n edu opencv numpy matplotlib tensorflow
#
# python -m ipykernel install --user --name edu

# %% [markdown]
# ## 설치 확인

# %%
import cv2
print (cv2.__version__)
# Out:
# 4.2.0

# %% [markdown]
# # 이미지 다루기

# %% [markdown]
# ## 이미지 읽기
#
# cv2.imread() 함수를 이용하여 이미지 파일을 읽습니다. 이미지 파일의 경로는 절대/상대경로가 가능합니다.
#
# - cv2.IMREAD_COLOR : 이미지 파일을 Color로 읽어들입니다. 투명한 부분은 무시되며, Default값입니다.
# - cv2.IMREAD_GRAYSCALE : 이미지를 Grayscale로 읽어 들입니다. 실제 이미지 처리시 중간단계로 많이 사용합니다.
# - cv2.IMREAD_UNCHANGED : 이미지파일을 alpha channel까지 포함하여 읽어 들입니다.
#
# *tip : 함수 마우스로 클릭 후 Shift + Tap 누르면 함수에 대한 정보가 뜬다.*

# %% [markdown]
# **cv2.imread(fileName, flag)**
# 이미지 파일을 flag값에 따라서 읽어들입니다.
#
# Parameters:
# - fileName (str) – 이미지파일의 경로
# - flag (int) – 이미지 파일을 읽을 때의 Option.
#
# Returns:
# - image객체 행렬
#
# Return type:
# - numpy.ndarray

# %%
import numpy as np
import cv2

# Load an color image in grayscale
img = cv2.imread('picture/logo.png',cv2.IMREAD_COLOR)

# %% [markdown]
# img값은 numpy의 ndarray type입니다.
# numpy는 python에서 수학적 처리를 위한 모듈로 openCV에서도 많이 사용됩니다.
# img가 어떤 형태의 행렬인지 확인을 해보려면 아래와 같이 입력합니다.

# %%
img.shape
# Out:
# (370, 300, 3)

# %% [markdown]
# 세로 370, 가로 300, 3채널(BGR, 컬러) 이미지

# %% [markdown]
# ## 이미지 보기
#
# cv2.imshow() 함수는 이미지를 사이즈에 맞게 보여줍니다.

# %% [markdown]
# **cv2.imshow(title, image)**
# 읽어들인 이미지 파일을 윈도우창에 보여줍니다.
#
# Parameters:
# - title (str) – 윈도우 창의 Title
# - image (numpy.ndarray) – cv2.imread() 의 return값

# %%
import numpy as np
import cv2

# # Load an color image in grayscale
img = cv2.imread('picture/logo.png',cv2.IMREAD_COLOR)

cv2.imshow('image',img)
#cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 이미지 저장하기
# cv2.imwrite() 함수를 이용하여 변환된 이미지나 동영상의 특정 프레임을 저장합니다.

# %% [markdown]
# **cv2.imwrite(fileName, image)**
# image파일을 저장합니다.
#
# Parameters:
# - fileName (str) – 저장될 파일명
# - image – 저장할 이미지

# %%
import cv2

img = cv2.imread('picture/logo.png', cv2.IMREAD_GRAYSCALE)



## logogray.png 라는 이미지로 저장하기
cv2.imwrite('imwrite.jpg',img)
# Out:
# True

# %% [markdown]
# ## Matplotlib 사용하기

# %% [markdown]
# openCV는 BGR로 사용하지만, Matplotlib는 RGB로 이미지를 보여주기 때문에 색공간을 바꿔 주어야 합니다.
#
# **cv2.cvtColor(img, cv2.COLOR_BGR2RGB)**
# - img : 이미지 소스
# - cv2.COLOR_BGR2RGB : BGR을 RGB로 변경

# %%
#-*- coding:utf-8 -*-
import cv2
from matplotlib import pyplot as plt # as는 alias 적용시 사용

img = cv2.imread('picture/lena.jpg', cv2.IMREAD_COLOR)

plt.imshow(img)
plt.xticks([]) # x축 눈금
plt.yticks([]) # y축 눈금
plt.show()

# %%
#-*- coding:utf-8 -*-
import cv2
from matplotlib import pyplot as plt # as는 alias 적용시 사용

img = cv2.imread('picture/lena.jpg', cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.xticks([]) # x축 눈금
plt.yticks([]) # y축 눈금
plt.show()

# %% [markdown]
# # 도형 그리기

# %% [markdown]
# ## Digital Image
#
# 디지털 영상은 2차원 행렬의 형태로 표현이 됩니다. 각 격자가 하나의 pixel이 됩니다. 이를 bitmap image라고 합니다.
# 각 pixel의 위치는 2가지 형태로 표현을 할 수가 있는데. 영상좌표와 행렬 위치로 표현이 됩니다.
# 영상 좌표는 좌측 상단의 꼭지점을 중심으로 (x,y)로 표현을 합니다. 행렬 위치는 (r,c)로 표현을 합니다. OpenCV에서 영상좌표와 행렬 위치 2가지 형태가 사용되기 때문에 유의해야 합니다.

# %% [markdown]
# ## Line 그리기
# Start와 End 점을 연결하여 직선을 그립니다.

# %% [markdown]
# **cv2.line(img, start, end, color, thickness)**
#
# Parameters:
# - img – 그림을 그릴 이미지 파일
# - start – 시작 좌표(ex; (0,0))
# - end – 종료 좌표(ex; (500. 500))
# - color – BGR형태의 Color(ex; (255, 0, 0) -> Blue)
# - thickness (int) – 선의 두께. pixel

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt # as는 alias 적용시 사용

#모두 0으로 되어 있는 빈 Canvas(검정색)
img = np.zeros((512, 512, 3), np.uint8)



### 선 그리기 ###
img = cv2.line(img, (511, 0), (0, 511), (255, 0, 0), 5)

###############



plt.imshow(img)

# %% [markdown]
# ## 사각형 그리기
# top-left corner와 bottom-right corner점을 연결하는 사각형을 그립니다.

# %% [markdown]
# **cv2.rectangle(img, start, end, color, thickness)**
# Parameters:
# - img – 그림을 그릴 이미지
# - start – 시작 좌표(ex; (0,0))
# - end – 종료 좌표(ex; (500. 500))
# - color – BGR형태의 Color(ex; (255, 0, 0) -> Blue)
# - thickness (int) – 선의 두께. pixel

# %%
### 사각형 그리기 ###
img = cv2.rectangle(img, (384, 0), (510, 128), (255,255,255), 4)

#################


plt.imshow(img)

# %% [markdown]
# ## 원 그리기
#
# **cv2.circle(img, center, radian, color, thickness)**
# Parameters:
# - img – 그림을 그릴 이미지
# - center – 원의 중심 좌표(x, y)
# - radian – 반지름
# - color – BGR형태의 Color
# - thickness – 선의 두께, -1 이면 원 안쪽을 채움

# %%
## 원 그리기 ##
img = cv2.circle(img, (10,10), 10, (0,0,10), -1)

############


plt.imshow(img)

# %% [markdown]
# ## 이미지에 Text 추가
#
# **cv2.putText(img, text, org, font, fontSacle, color)**
# Parameters:
# - img – image
# - text – 표시할 문자열
# - org – 문자열이 표시될 위치. 문자열의 bottom-left corner점
# - font – font type. CV2.FONT_XXX
# - fontSacle – Font Size
# - color – fond color

# %%
### Text 추가 ###
cv2.putText(img, 'OpenCV', (10,500), cv2.FONT_HERSHEY_SIMPLEX, 4, (255,255,255), 2)

###############



plt.imshow(img)

# %% [markdown]
# # Basic Operation

# %% [markdown]
# ## Pixel Value

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt # as는 alias 적용시 사용

img = cv2.imread('picture/logo.png')
plt.imshow(img)
print(img.shape)
# Out:
# (370, 300, 3)

# %%
print(img[200,30])
# Out:
# [  0 255   0]

# %% [markdown]
# ## 이미지 ROI
#
# 이미지 작업시에는 특정 pixel단위 보다는 특정 영역단위로 작업을 하게 됩니다. 이것을 Region of Image(ROI)라고 합니다. ROI 설정은 Numpy의 indexing방법을 사용합니다. 만일 아래와 같이 특정 영역에 어떤 물체가 있다는 것을 알고 있으면 그 영역을 설정해서 Copy를 할 수도 있습니다.

# %%
img = cv2.imread('picture/son.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = cv2.imread('picture/son.jpg')


##### 공 복사 #####

ball = img[340:390, 245:300] # img[행의 시작점: 행의 끝점, 열의 시작점: 열의 끝점]
img[340:390,405:460] = ball # 동일 영역에 Copy
#img[25:75,265:320] = ball

##################


img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# # 이미지 연산

# %% [markdown]
# ## 이미지 더하기
#
# 이미지를 더하는 방법은 OpenCV의 `cv2.add()` 함수를 사용하는 방법과
# Numpy 연산, 즉 img1 + img2로 하는 방법이 있습니다. 둘다 더하는 것은 같지만 결과는 다르게 나타납니다.
# OpenCV의 `cv2.add()` 는 Saturation 연산을 하고, Numpy는 modulo 연산을 합니다.

# %% [markdown]
# **Saturation**연산은 한계값을 정하고 그 값을 벗어나는 경우는 모두 특정 값으로 계산하는 방식 입니다.
# 이미지에서는 0이하는 모두 0, 255이상은 모두 255로 표현하는 것입니다.
# **modulo**연산은 a와 b는 n으로 나눈 나머지 값이 같다라는 의미입니다.
# 시계를 예로 들면 2와 14는 12로 나눈 나머지가 2로 동일합니다. 이미지에서는 연산의 결과가 256보다 큰 경우는 256으로 나눈 나머지 값으로 결정을 합니다.

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt # as는 alias 적용시 사용

img1 = cv2.imread('picture/flower1.jpg')
img2 = cv2.imread('picture/flower2.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

img_res1 = img1+img2
img_res2 = cv2.add(img1,img2)

plt.imshow(img_res1)
plt.show()

plt.imshow(img_res2)
plt.show()

# %% [markdown]
# ## 이미지 Blending
# 이미지를 서로 합칠 때 가중치를 두어 합치는 방법입니다.
#
# $$g(x)=(1−α)f0(x)+αf1(x)$$
#
# $α$ 값이 0 -> 1로 변함에 따라서 이미지가 전환된다.

# %%
#-*- coding:utf-8 -*-
import cv2
import numpy as np
from matplotlib import pyplot as plt # as는 alias 적용시 사용

img1 = cv2.imread('picture/flower1.jpg')
img2 = cv2.imread('picture/flower2.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

w = 0 # 가중치

dst = cv2.addWeighted(img1,float(100-w) * 0.01, img2,float(w) * 0.01,0)
plt.imshow(dst)
